# %%
import numpy as np
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/amongnikol/belajaraDataScienceJCOp/refs/heads/main/course1-pengantarMachineLearning/data/cereal.csv")
df.head(10)
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
# 5    Apple Cinnamon Cheerios   G    C       110        2    2     180    1.5
# 6                Apple Jacks   K    C       110        2    0     125    1.0
# 7                    Basic 4   G    C       130        3    2     210    2.0
# 8                  Bran Chex   R    C        90        2    1     200    4.0
# 9                Bran Flakes   P    C        90        3    0     210    5.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     76 non-null     float64
#  9   sugars    76 non-null     float64
#  10  potass    75 non-null     float64
#  11  vitamins  77 non-null     object
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(7), int64(5), object(4)
# memory usage: 9.8+ KB

# %%
# mask 
df[df.rating > 70]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 3     8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 64   19.0     0.0   140.0    FDA_0      1     1.0  0.67  74.472949
# 65   20.0     0.0   120.0    FDA_0      1     1.0  0.67  72.801787

# %%
# selain 1
df[-(df.shelf == 1)]
# Out:
#                                       name mfr type  calories  protein  fat  \
# 0                                100% Bran   N    C        70        4    1
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 12                   Cinnamon Toast Crunch   G    C       120        1    3
# 13                                Clusters   G    C       110        3    2
# ...

# %%
# menggabungkan beberapa kondisi
df[(df.rating > 50) & (df.fat == 0)]
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 9                 Bran Flakes   P    C        90        3    0     210    5.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 26        Frosted Mini-Wheats   K    C       100        3    0       0    3.0
# 33                 Grape-Nuts   P    C       110        3    0     170    3.0
# 50          Nutri-grain Wheat   K    C        90        3    0     170    3.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# ...

# %%
df[df.mfr.isin(["K", "N"]) | (df.rating > 70)]
# Out:
#                            name mfr type  calories  protein  fat  sodium  \
# 0                     100% Bran   N    C        70        4    1     130
# 2                      All-Bran   K    C        70        4    1     260
# 3     All-Bran with Extra Fiber   K    C        50        4    0     140
# 6                   Apple Jacks   K    C       110        2    0     125
# 16                  Corn Flakes   K    C       100        2    0     290
# 17                    Corn Pops   K    C       110        1    0      90
# 19           Cracklin' Oat Bran   K    C       110        3    3     140
# 20       Cream of Wheat (Quick)   N    H       100        3    0      80
# 21                      Crispix   K    C       110        2    0     220
# 24                  Froot Loops   K    C       110        2    1     125
# 25               Frosted Flakes   K    C       110        1    0     200
# 26          Frosted Mini-Wheats   K    C       100        3    0       0
# ...

# %%
# direkomendasikan menggunakan .copy() agar tidak mengubah dataframe utama
df_my_preferences = df[(df.rating > 60) & (df.mfr.isin(['K','N']))].copy()
df_my_preferences
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0     5.0     6.0   280.0   FDA_25      3    1.00  0.33  68.402973
# 3     8.0     0.0   330.0   FDA_25      3    1.00  0.50  93.704912
# 20   21.0     0.0     NaN    FDA_0      2    1.00  1.00  64.533816
# 63   16.0     0.0    95.0    FDA_0      1    0.83  1.00  68.235885
# 64   19.0     0.0   140.0    FDA_0      1    1.00  0.67  74.472949
# ...

# %%
df_my_preferences.sort_values('rating',ascending=True)
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 20     Cream of Wheat (Quick)   N    H       100        3    0      80    1.0
# 63             Shredded Wheat   N    C        80        2    0       0    3.0
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 65  Shredded Wheat spoon size   N    C        90        3    0       0    3.0
# 64     Shredded Wheat 'n'Bran   N    C        90        3    0       0    4.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
#
#     carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 20   21.0     0.0     NaN    FDA_0      2    1.00  1.00  64.533816
# 63   16.0     0.0    95.0    FDA_0      1    0.83  1.00  68.235885
# 0     5.0     6.0   280.0   FDA_25      3    1.00  0.33  68.402973
# 65   20.0     0.0   120.0    FDA_0      1    1.00  0.67  72.801787
# 64   19.0     0.0   140.0    FDA_0      1    1.00  0.67  74.472949
# ...

# %% [markdown]
# # Groupby

# %%
df_grouped = df.drop(['name','mfr','type','vitamins'], axis=1).copy()
df_grouped.groupby('shelf').mean()
# Out:
#          calories   protein   fat      sodium     fiber      carbo    sugars  \
# shelf
# 1      102.500000  2.650000  0.60  176.250000  1.685000  16.684211  5.105263
# 2      109.523810  1.904762  1.00  145.714286  0.904762  13.619048  9.619048
# 3      107.777778  2.861111  1.25  158.611111  3.138889  14.500000  6.527778
#
#            potass    weight      cups     rating
# shelf
# 1       75.500000  0.991500  0.897000  46.145439
# 2       60.750000  1.015714  0.911429  34.972827
# 3      133.571429  1.058889  0.726111  45.220032

# %%
df_grouped.groupby(['fat', 'shelf']).mean()
# Out:
#              calories   protein      sodium     fiber      carbo     sugars  \
# fat shelf
# 0   1      101.818182  2.272727  159.545455  1.181818  18.000000   4.545455
#     2      102.000000  2.200000   62.000000  1.800000  14.800000   7.600000
#     3       87.272727  2.545455  150.909091  3.272727  15.181818   3.545455
# 1   1      101.666667  2.500000  216.666667  2.416667  15.250000   6.000000
#     2      110.833333  1.833333  162.500000  0.583333  13.583333  10.500000
#     3      105.833333  2.916667  182.083333  3.500000  14.416667   7.000000
# 2   1      106.666667  4.333333  156.666667  2.066667  13.750000   5.500000
#     2      113.333333  2.000000  196.666667  1.000000  12.000000   9.666667
#     3      125.000000  2.875000  173.750000  2.500000  14.875000   8.875000
# 3   2      120.000000  1.000000  210.000000  0.000000  13.000000   9.000000
#     3      132.500000  3.500000  115.000000  3.250000  13.750000   8.250000
# ...

# %%
df_grouped.groupby(['fat', 'shelf']).size()
# Out:
# fat  shelf
# 0    1        11
#      2         5
#      3        11
# 1    1         6
#      2        12
#      3        12
# 2    1         3
#      2         3
#      3         8
# 3    2         1
#      3         4
# 5    3         1
# dtype: int64

# %%
df.pivot_table(index='mfr', columns='vitamins', values='rating')
# Out:
# vitamins      FDA_0    FDA_100     FDA_25
# mfr
# A               NaN        NaN  54.850917
# G               NaN  38.030458  33.926177
# K               NaN  38.166245  44.919295
# N         70.011109        NaN  63.883483
# P               NaN        NaN  41.705744
# Q         52.143457        NaN  33.688523
# R               NaN        NaN  41.542997

# %% [markdown]
# # new column and drop column

# %%
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %%
df['kolom_baru'] = np.random.rand(len(df))
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating  kolom_baru
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973    0.720491
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679    0.891227
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505    0.295417
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912    0.790037
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843    0.077859

# %%
df.drop('kolom_baru', axis=1, inplace=True)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %% [markdown]
# # Map, Apply, dan Transform

# %%
df['shelf_name'] = df.shelf.map({1:'bawah', 2:'tengah', 3:'atas'})
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating shelf_name
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843       atas

# %%
def convert_g_to_mg(x):
    return 1000*x

def convert_to_lower(x):
    return x.lower()

df['fat_mg'] = df.fat.apply(convert_g_to_mg)
df['mfr_lower'] = df.mfr.apply(convert_to_lower)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating shelf_name  \
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843       atas
#
#    fat_mg mfr_lower
# ...

# %%
# menggunakan lambda function
df['protein_mg'] = df.protein.apply(lambda x: x*1000)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating shelf_name  \
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973       atas
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679       atas
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505       atas
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912       atas
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843       atas
#
#    fat_mg mfr_lower  protein_mg
# ...

# %%
# scaling
df['scaled_rating'] = df.rating.transform(lambda x: (x-x.min())/(x.max()-x.min()))
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  ...  vitamins shelf  weight  cups     rating  shelf_name  \
# 0    5.0     6.0  ...    FDA_25     3     1.0  0.33  68.402973        atas
# 1    8.0     8.0  ...     FDA_0     3     1.0  1.00  33.983679        atas
# 2    7.0     5.0  ...    FDA_25     3     1.0  0.33  59.425505        atas
# 3    8.0     0.0  ...    FDA_25     3     1.0  0.50  93.704912        atas
# 4   14.0     8.0  ...    FDA_25     3     1.0  0.75  34.384843        atas
#
#   fat_mg  mfr_lower protein_mg  scaled_rating
# ...

# %%
df.drop(['shelf_name', 'fat_mg', 'mfr_lower', 'protein_mg', 'scaled_rating'], axis=1, inplace=True)
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843

# %% [markdown]
# # one-hot encoding/ dummy variable(mengubah data kategorikal -> numerik)

# %%
df_encode = pd.get_dummies(df, columns=['vitamins'])
df_encode.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  shelf  weight  cups     rating  vitamins_FDA_0  \
# 0    5.0     6.0   280.0      3     1.0  0.33  68.402973           False
# 1    8.0     8.0   135.0      3     1.0  1.00  33.983679            True
# 2    7.0     5.0   320.0      3     1.0  0.33  59.425505           False
# 3    8.0     0.0   330.0      3     1.0  0.50  93.704912           False
# 4   14.0     8.0     NaN      3     1.0  0.75  34.384843           False
#
#    vitamins_FDA_100  vitamins_FDA_25
# ...

# %% [markdown]
# # binning(mengubah numerik -> kategorikal)

# %%
df.sodium.hist(bins=10)
# Out:
# <Axes: >

# %%
df['sodium_bin'] = pd.cut(df.sodium, bins=3, labels=['low', 'medium', 'high'])
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating sodium_bin
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973     medium
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679        low
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505       high
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912     medium
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843     medium

# %%
df['sodium_bin'] = pd.cut(df.sodium, bins=[0,100,200, df.sodium.max()], labels=['low', 'medium', 'high'])
df.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass vitamins  shelf  weight  cups     rating sodium_bin
# 0    5.0     6.0   280.0   FDA_25      3     1.0  0.33  68.402973     medium
# 1    8.0     8.0   135.0    FDA_0      3     1.0  1.00  33.983679        low
# 2    7.0     5.0   320.0   FDA_25      3     1.0  0.33  59.425505       high
# 3    8.0     0.0   330.0   FDA_25      3     1.0  0.50  93.704912     medium
# 4   14.0     8.0     NaN   FDA_25      3     1.0  0.75  34.384843     medium
